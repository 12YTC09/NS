# %%
#2-D Linear Convection


#New Library required for projected 3D plots
from mpl_toolkits.mplot3d import Axes3D 

import numpy
from matplotlib import pyplot,cm
# %matplotlib inline


#variable declarations
nx = 81  #X
ny = 81  #y

nt = 100 #time

c =1 
dx = 2 / (nx -1)
dy = 2 / (ny -1)

sigma = .2
dt =sigma * dx

x = numpy.linspace(0,2,nx)
y = numpy.linspace(0,2,ny)

u = numpy.ones((ny,nx))
un = numpy.ones((ny,nx))

###Assign initial conditions

##set hat function I.C. : u(.5<=x<=1 && .5 <=y<=1) is 2
u[int(.5/dy):int(1/dy+1),int(.5/dx):int(1/dx+1)] = 2


###Plot Initial Condition
##the figure parameter can be used to produce different sized images

#create a new figure,or activate aan existing figure 
fig = pyplot.figure(figsize=(11,7),dpi=100)

#Get the current axes,creating one if necessary
ax =fig.gca(projection='3d')

#Return coordinate matrices from coordinate vectors
X,Y = numpy.meshgrid(x,y)

surf=ax.plot_surface(X,Y,u[:],cmap=cm.viridis)

# %%
numpy.ones((3,2))
# Out:
# array([[1., 1.],
#        [1., 1.],
#        [1., 1.]])

# %% [markdown]
# # 3D Plotting Notes
#
# ```python=
# #To plot a projected 3D result
#
# from mpl_toolkits.mplot3d import Axes3D
#
#
# #The figsize and dpi commands are optional and simply specify the size and resolution of the figure being produced.
# fig = pyplot.figure(figsize=(11, 7), dpi=100)
#
#
# #
# ax = fig.gca(projection='3d')
#
#
#
# surf2 = ax.plot_surface(X, Y, u[:])
#
#
#
#
# ```

# %%
#Iterating in two dimensions

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('tUg_dE3NXoY')
